# %%
# Setup: git pull & pip install
# !git clone https://github.com/DanMatsu0/hello-colab.git || (cd hello-colab && git pull)
# %cd hello-colab
# !pip install -r requirements.txt

# %%
# Run main.py
# !python main.py
